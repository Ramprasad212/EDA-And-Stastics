# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
a= np.array([2+3j,2-3j])
a.dtype
# Out:
# dtype('complex128')

# %%
a= np.array([1.2,3.4,5,6])
a.dtype
# Out:
# dtype('float64')

# %%
bin(530)
# Out:
# '0b1000010010'

# %%
a = np.array([429,530,-189,289,-6,7,8],dtype='int8')
print(a)
print(a.dtype)
print(a.nbytes)
print(a.itemsize)
# Out:
# [-83  18  67  33  -6   7   8]
# int8
# 7
# 1
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16564\286805439.py:1: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of 429 to int8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   a = np.array([429,530,-189,289,-6,7,8],dtype='int8')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16564\286805439.py:1: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of 530 to int8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   a = np.array([429,530,-189,289,-6,7,8],dtype='int8')
# ...

# %%
a = np.array([429,-530,189,289,-6,7,8],dtype='uint16')
print(a)
print(a.dtype)
print(a.nbytes)
print(a.itemsize)
# Out:
# [  429 65006   189   289 65530     7     8]
# uint16
# 14
# 2
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16564\2330472832.py:1: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of -530 to uint16 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   a = np.array([429,-530,189,289,-6,7,8],dtype='uint16')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16564\2330472832.py:1: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of -6 to uint16 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   a = np.array([429,-530,189,289,-6,7,8],dtype='uint16')

# %%
a = np.array([429,-530,189,289,-6,7,8],dtype='int16')
print(a)
print(a.dtype)
print(a.nbytes)
print(a.itemsize)
# Out:
# [ 429 -530  189  289   -6    7    8]
# int16
# 14
# 2

# %%
a = np.array([429,530,189,289,6,7,8])
print(a)
print(a.dtype)
print(a.nbytes)
print(a.itemsize)
# Out:
# [429 530 189 289   6   7   8]
# int32
# 28
# 4

# %%
bin(200)
# Out:
# '0b11001000'

# %%
import numpy as np
a=np.array([1,2,3,200])
print(a.dtype)
print(a.itemsize)
print(a.itemsize * a.size)
print(a.nbytes)
# Out:
# int32
# 4
# 16
# 16

# %%
bin(200)
# Out:
# '0b11001000'

# %%
import numpy as np
a=np.array([1,2,3,200],dtype='int8')
print(a.dtype)
print(a.itemsize)
print(a.itemsize * a.size)
print(a.nbytes)
# Out:
# int8
# 1
# 4
# 4
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16564\2642369679.py:2: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of 200 to int8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   a=np.array([1,2,3,200],dtype='int8')

# %%
a.nbytes
# Out:
# 16

# %%
a = np.array([4,5,18,289])

# %% [markdown]
# https://numpy.org/doc/stable/reference/arrays.dtypes.html#dtype

# %%
a = np.array([1,2,-3,254])
print(a.dtype)
print(a.itemsize)
print(a.nbytes)
# Out:
# int32
# 4
# 16

# %%
a = np.array([1,2,-3,254],dtype='int16')
print(a.dtype)
print(a.itemsize)
print(a.nbytes)
# Out:
# int16
# 2
# 8

# %%
a = np.array([1,2,-3,254],dtype='uint8')
print(a.dtype)
print(a.itemsize)
print(a.nbytes)
# Out:
# uint8
# 1
# 4
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16564\653716273.py:1: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of -3 to uint8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   a = np.array([1,2,-3,254],dtype='uint8')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(6.55E+04)
# Out:
# 65500.0

# %%
2**15
# Out:
# 32768

# %%
print(-6.55e+04,6.55e+04)
# Out:
# -65500.0 65500.0

# %%
(2**16)-1
# Out:
# 65535

# %%
a=np.array([1,2,3,4,127])
a.dtype
# Out:
# dtype('int32')

# %%
a=np.array([1,2,3,4,127],dtype="int8")
a.dtype
# Out:
# dtype('int8')

# %%
a=np.array([1,2,3,4,253],dtype="uint8")
print(a.dtype)
print(a)
# Out:
# uint8
# [  1   2   3   4 253]

# %%
a=np.array([1,2,-3,4,253],dtype="int16")
print(a.dtype)
print(a)
# Out:
# int16
# [  1   2  -3   4 253]

# %%
-2**(32-1),2**(32-1)-1
# Out:
# (-2147483648, 2147483647)

# %%
# (- 2 ** n-1 ),( 2 ** n-1 )-1

# %%
a= np.array([1,2,3,-10,100,150,32768837464882])
print(a)
print(a.dtype)
print(a.nbytes)
# Out:
# [             1              2              3            -10
#             100            150 32768837464882]
# int64
# 56

# %%
a= np.array([1,2,3,-10,100,126],dtype="int8")
print(a)
print(a.dtype)
print(a.nbytes)
# Out:
# [  1   2   3 -10 100 126]
# int8
# 6

# %%
a= np.array([1,2,3,-10,100,126])
print(a)
print(a.dtype)
print(a.nbytes)
# Out:
# [  1   2   3 -10 100 126]
# int32
# 24

# %%
-6.55e+04
# Out:
# -65500.0

# %%
k=np.array([1,2,655.5],dtype='float16')
print(k.dtype)
print(k)
# Out:
# float16
# [  1.    2.  655.5]

# %%
a=np.array([1,2,3000,4,5,612])
print(a.dtype)
print(a.itemsize) #bytes for each number
print(a.nbytes) #bytes for the entire array
# Out:
# int32
# 4
# 24

# %%
a=np.array([1,2,3000,4,5,612],dtype='int16')
print(a)
print(a.itemsize) #bytes for each number
print(a.nbytes)
# Out:
# [   1    2 3000    4    5  612]
# 2
# 12

# %%
a=np.array([1,2,3,4])
print(a.dtype)
print(a.itemsize)
print(a.nbytes)
# Out:
# int32
# 4
# 16

# %%
import numpy as np
a=np.array([1.6,2.1,3.3,4.5,38.2])
print(a.dtype)
print(a.nbytes)
print(a)
# Out:
# float64
# 40
# [ 1.6  2.1  3.3  4.5 38.2]

# %%
import numpy as np
a=np.array([1.6,2.1,3.3,4.5,38.2],dtype="float16")
print(a.dtype)
print(a.nbytes)
print(a)
# Out:
# float16
# 10
# [ 1.6  2.1  3.3  4.5 38.2]

# %%
1

# %%
import numpy as np
b = np.array(['apple', 'water', 'banana', 'cherry', 'peach'])
print(b.dtype)
print(b.itemsize)
# it is U6.... # 1 character = 4 bytes of memory 
# and ...6 character...# 6*4 =24bytes of memory
print(b.nbytes)
# Out:
# <U6
# 24
# 120

# %%
import numpy as np
b = np.array(['apple', 'watermelon', 'banana', 'cherry', 'peach'])
print(b.itemsize)
print(b.nbytes)
print(b.dtype)
# Out:
# 40
# 200
# <U10

# %% [markdown]
# Unicode is a standard for working with a wide range of characters. Each symbol has a code point (a number), and these code points can be encoded (converted to a sequence of bytes) using a variety of encodings.

# %% [markdown]
# In Python 3, Unicode strings are the default. The type str is a collection of Unicode code points, and the type bytes is used for representing collections of 8-bit integers (often interpreted as ASCII characters).

# %%
ord('A')
# Out:
# 65

# %%
print('\u0041')
# Out:
# A

# %%
print('\u0041\u0042\u0043')
# Out:
# ABC

# %% [markdown]
# **type conversion in numpy**

# %%
f= np.array([1,2,3,4,5.0])
print(f.dtype)
print(f)
# Out:
# float64
# [1. 2. 3. 4. 5.]

# %%
f= np.array([1,2,3,4,5.0],dtype='int8')
print(f.dtype)
print(f)
# Out:
# int8
# [1 2 3 4 5]

# %%
f= np.array([1,2,3,4,5.0])
f
# Out:
# array([1., 2., 3., 4., 5.])

# %%
f= np.array([1,2,3,4,5.0])
print(f.dtype)
f= f.astype('int') #as type will not change the original 
print(f)
print(f.dtype)
# Out:
# float64
# [1 2 3 4 5]
# int32

# %%
f = np.array([1,2,3,'30'])
f
# Out:
# array(['1', '2', '3', '30'], dtype='<U11')

# %%
f= f.astype('int')
f
# Out:
# array([ 1,  2,  3, 30])

# %%
f= f.astype('int')
f

# %%
f= f.astype('i')
f
# Out:
# array([ 1,  2,  3, 30], dtype=int32)

# %%
f= np.array(['ramya','python','data'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 f= np.array(['ramya','python','data'],dtype='int32')
#       2 print(f)
#       3 print(f.dtype)
#
# ValueError: invalid literal for int() with base 10: 'ramya'

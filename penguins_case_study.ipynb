# %%
import seaborn as sns

# %%
df = sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # 1. a UNIVARIATE CATEGORICAL

# %%
#1.a which gender groups penguins are more?
sns.countplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # male group penguins are more

# %%
#1.b which island groups penguins are more?
sns.countplot(data=df,x='island')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# # in biscoe islands lot of penguins are there

# %% [markdown]
# # 1.b Univariate Numerical

# %%
# check flipper_length distribution
sns.kdeplot(data=df,x='flipper_length_mm')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.histplot(data=df,x='flipper_length_mm',bins=[170,180,190,200,210,220,230,240])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# # between flipper length is 190 to 200 lot of penguins are there from data
# # between flipper length is 210 to 220 also next highest count of penguins are there here

# %%
# box plot

# %%
# scatter plot
sns.scatterplot(data=df['flipper_length_mm'])
# Out:
# <Axes: ylabel='flipper_length_mm'>

# %%
sns.stripplot(data=df['flipper_length_mm'])
# Out:
# <Axes: ylabel='flipper_length_mm'>

# %% [markdown]
# # between flipper length is 190 to 200 lot of penguins are there from data
# # between flipper length is 210 to 220 also next highest count of penguins are there here

# %% [markdown]
# # 2. Bivariate

# %%
# for which species how flipper_length_mm is varying
sns.barplot(data=df,x='species',y='flipper_length_mm',estimator='max',errorbar=None)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.barplot(data=df,x='species',y='flipper_length_mm',estimator='max',hue='sex',errorbar=None)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# # penguin with highest flipper length is present in gentoo species

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.barplot(data=df,x='island',y='body_mass_g',estimator='min',errorbar=None)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %% [markdown]
# # the penguin with least body mass is present from dream islands

# %%
sns.barplot(data=df,x='sex',y='body_mass_g',errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %% [markdown]
# # on an average body mass is high for male penguins group

# %%
sns.boxplot(data=df,x='sex',y='body_mass_g')
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
sns.boxplot(df['body_mass_g'])
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
df['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339       NaN
# 340    4850.0
# 341    5750.0
# 342    5200.0
# 343    5400.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
new= df.loc[(df['species']=='Chinstrap') & (df['sex']=='Male'),'body_mass_g']
new
# Out:
# 153    3900.0
# 154    3650.0
# 156    3725.0
# 159    3750.0
# 161    3700.0
# 163    3775.0
# 165    4050.0
# 167    4050.0
# 168    3300.0
# 171    4400.0
# 173    3400.0
# 175    3800.0
# 177    4150.0
# 179    3800.0
# 181    4550.0
# 183    4300.0
# 185    4100.0
# 186    3600.0
# 189    4800.0
# 191    4500.0
# 192    3950.0
# 194    3550.0
# 197    4450.0
# 199    4300.0
# 200    3250.0
# 203    3950.0
# 205    4050.0
# 207    3450.0
# 209    4050.0
# 210    3800.0
# 212    3950.0
# 215    4000.0
# 217    3775.0
# 218    4100.0
# Name: body_mass_g, dtype: float64

# %%
sns.boxplot(new)
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
sns.boxplot(data=df,x='sex',y='body_mass_g',hue='species')
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# how bill length and bill depth are related?
sns.scatterplot(data=df,x='bill_length_mm',y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=df,x='bill_length_mm',y='bill_depth_mm',hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=df,x='bill_length_mm',y='bill_depth_mm',hue='species',style='sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
print(df['bill_length_mm'].cov(df['bill_depth_mm']))
print(df['bill_length_mm'].corr(df['bill_depth_mm']))
# Out:
# -2.5342339352780776
# -0.2350528703555326

# %%
sns.scatterplot(data=df,x='bill_length_mm',y='flipper_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
print(df['bill_length_mm'].cov(df['flipper_length_mm']))
print(df['bill_length_mm'].corr(df['flipper_length_mm']))
# Out:
# 50.375765292997876
# 0.6561813407464278

# %%
import pandas as pd
df1= pd.DataFrame({'x':[1,2,3,4],
                   'y' :[1,4,9,16],
                  'z':['a','a','b','b']})
df1
# Out:
#    x   y  z
# 0  1   1  a
# 1  2   4  a
# 2  3   9  b
# 3  4  16  b

# %%
sns.lineplot(data=df1,x='x',y='y',hue='z')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.lineplot(data=df,x='bill_length_mm',y='flipper_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
import pandas as pd
df1= pd.DataFrame({"x":[1,2,3,4,5],
                   "y":[1,4,9,16,25]})
df1
# Out:
#    x   y
# 0  1   1
# 1  2   4
# 2  3   9
# 3  4  16
# 4  5  25

# %%
sns.lineplot(data=df1,x='x',y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
import seaborn as sns
f = sns.load_dataset('flights')
f
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
new= f.groupby(by='year').sum('passengers')
new.reset_index(inplace=True)
new
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(data=new,x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
f
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
temp = f.groupby(by='month',observed=False)[['passengers']].sum()
temp.reset_index(inplace=True)

# %%
temp
# Out:
#    month  passengers
# 0    Jan        2901
# 1    Feb        2820
# 2    Mar        3242
# 3    Apr        3205
# 4    May        3262
# 5    Jun        3740
# 6    Jul        4216
# 7    Aug        4213
# 8    Sep        3629
# 9    Oct        3199
# 10   Nov        2794
# 11   Dec        3142

# %%
sns.lineplot(data= temp,x='month',y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=df,x='bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
plt.figure(figsize=(5,4))
sns.kdeplot(data=df,x='bill_length_mm',hue='sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
#1
sns.jointplot(data=df,x='bill_length_mm',y='flipper_length_mm')
plt.show()

# %%
plt.figure(figsize=(5,1))
sns.kdeplot(data=df,x='bill_length_mm',hue='sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.jointplot(data=df,x='bill_length_mm',y='flipper_length_mm',hue='sex')
plt.show()

# %%
#2
sns.jointplot(data=df,x='bill_length_mm',y='flipper_length_mm',kind='hex')
plt.show()

# %%
a= sns.JointGrid(data=df,x='bill_length_mm',y='flipper_length_mm')
a.plot(sns.scatterplot,sns.kdeplot)

# %%
sns.jointplot(data=df,x='bill_length_mm',y='flipper_length_mm')
plt.show()

# %%
plot2= sns.JointGrid(data=df,x='bill_length_mm',y='flipper_length_mm')
plot2.plot(sns.scatterplot,sns.histplot)

# %%
# which species are present in which islands?

pd.crosstab(df['species'],df['sex'])
# Out:
# sex        Female  Male
# species
# Adelie         73    73
# Chinstrap      34    34
# Gentoo         58    61

# %%
sns.heatmap(pd.crosstab(df['species'],df['sex']))
# Out:
# <Axes: xlabel='sex', ylabel='species'>

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
new_df = df.select_dtypes(include='number')
new_df
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 3               NaN            NaN                NaN          NaN
# 4              36.7           19.3              193.0       3450.0
# ..              ...            ...                ...          ...
# 339             NaN            NaN                NaN          NaN
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [344 rows x 4 columns]

# %%
sns.heatmap(new_df.corr())
# Out:
# <Axes: >

# %%
sns.histplot(data=df,x='bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(50,10))
sns.pairplot(df,hue='species')
plt.show()
